# %% [markdown]
# ### Análise de Dados: Hospital Santa Casa Goiânia - GO

# %% [markdown]
# ---

# %% [markdown]
# #### Importar bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---

# %% [markdown]
# #### Importar base para análise de dados

# %%
data = pd.read_csv('Documents/analisehospital/agendamentoslabels.csv')

# %% [markdown]
# ---

# %% [markdown]
# #### DataFrame dos dados

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#           id                 protocolo  tipo_retorno  \
# 0         88  202301181755359135778457             1
# 1       5023  202302231341593531386745             1
# 2       4512   20230217154540306821975             1
# 3       5727  202302281704491125985199             1
# 4          6  202301161755176828621602             1
# ...      ...                       ...           ...
# 14513  14687   20230519151820868583611             1
# 14514  14688   20230519151836885685296             1
# 14515  14689  202305191521521091241441             1
# 14516  14690  202305191522471148733497             1
# 14517  14691  202305191523391203031178             1
#
#                                  nome_paciente data_nascimento  \
# 0                     camila araujo dos santos      1983-06-03
# 1                       guiomar alves da silva      1963-10-22
# 2      Efig�nia Francisco da Conceição Lacerda      1962-09-20
# 3                      Valdeci Alves Fernandes      1959-06-23
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### Verificando se possui valores nulos nas colunas

# %%
pd.isnull(df).sum()
# Out:
# id                                        0
# protocolo                                 0
# tipo_retorno                              0
# nome_paciente                             0
# data_nascimento                           0
# nome_mae                                  0
# numero_celular                            0
# prontuario                             6151
# numero_telefone                        4783
# email                                  3012
# genero                                    0
# nome_medico                            2568
# data_ultima_consulta                   5423
# tipo_vaga                                 0
# data_alta_internacao                  11661
# especialidade_medica                      0
# tipo_marca                            13241
# tipo_confirmacao_agendamento              0
# observacao                            12003
# status_agendamento                     7765
# data_hora_agendamento                  9958
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### Verificando a porcentagem de valores que estão faltando

# %%
df.isna().mean()
# Out:
# id                                    0.000000
# protocolo                             0.000000
# tipo_retorno                          0.000000
# nome_paciente                         0.000000
# data_nascimento                       0.000000
# nome_mae                              0.000000
# numero_celular                        0.000000
# prontuario                            0.423681
# numero_telefone                       0.329453
# email                                 0.207467
# genero                                0.000000
# nome_medico                           0.176884
# data_ultima_consulta                  0.373536
# tipo_vaga                             0.000000
# data_alta_internacao                  0.803210
# especialidade_medica                  0.000000
# tipo_marca                            0.912040
# tipo_confirmacao_agendamento          0.000000
# observacao                            0.826767
# status_agendamento                    0.534853
# ...

# %% [markdown]
# #### Apresentação dos dados textuais

# %%
dataText = df[['status_agendamento', 'data_criacao']]

# %%
dataText
# Out:
#        status_agendamento         data_criacao
# 0                     3.0  2023-01-18 08:20:58
# 1                     2.0  2023-02-23 10:41:59
# 2                     2.0  2023-02-17 12:44:05
# 3                     2.0  2023-02-28 14:04:49
# 4                     2.0  2023-01-16 08:03:18
# ...                   ...                  ...
# 14513                 NaN  2023-05-19 12:18:20
# 14514                 NaN  2023-05-19 12:18:36
# 14515                 NaN  2023-05-19 12:21:52
# 14516                 NaN  2023-05-19 12:22:47
# 14517                 NaN  2023-05-19 12:23:39
#
# [14518 rows x 2 columns]

# %%
pd.isnull(dataText).sum()
# Out:
# status_agendamento    7765
# data_criacao             0
# dtype: int64

# %%
dataText.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14518 entries, 0 to 14517
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   status_agendamento  6753 non-null   float64
#  1   data_criacao        14518 non-null  object
# dtypes: float64(1), object(1)
# memory usage: 227.0+ KB

# %% [markdown]
# #### Transformar a coluna de data de Object para Datetime

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14518 entries, 0 to 14517
# Data columns (total 27 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  14518 non-null  int64
#  1   protocolo                           14518 non-null  object
#  2   tipo_retorno                        14518 non-null  int64
#  3   nome_paciente                       14518 non-null  object
#  4   data_nascimento                     14518 non-null  object
#  5   nome_mae                            14518 non-null  object
#  6   numero_celular                      14518 non-null  object
#  7   prontuario                          8367 non-null   float64
#  8   numero_telefone                     9735 non-null   object
#  9   email                               11506 non-null  object
#  10  genero                              14518 non-null  int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14518 entries, 0 to 14517
# Data columns (total 27 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  14518 non-null  int64
#  1   protocolo                           14518 non-null  object
#  2   tipo_retorno                        14518 non-null  int64
#  3   nome_paciente                       14518 non-null  object
#  4   data_nascimento                     14518 non-null  object
#  5   nome_mae                            14518 non-null  object
#  6   numero_celular                      14518 non-null  object
#  7   prontuario                          8367 non-null   float64
#  8   numero_telefone                     9735 non-null   object
#  9   email                               11506 non-null  object
#  10  genero                              14518 non-null  int64
# ...

# %%
acunputura = df.especialidade_medica == 1

# %%
a = acunputura.mean()

# %%
a
# Out:
# 0.0005510400881664141

# %%
cardiologia = df.especialidade_medica == 2

# %%
b = cardiologia.mean()

# %%
b
# Out:
# 0.11316985810717729

# %%
cardioPacienteRNI = df.especialidade_medica == 3

# %%
c = cardioPacienteRNI.mean()

# %%
c
# Out:
# 0.002273040363686458

# %%
cardioArritmia = df.especialidade_medica == 4

# %%
d = cardioArritmia.mean()

# %%
d
# Out:
# 0.019768563162970106

# %% [markdown]
# ---

# %% [markdown]
# #### Conversão do atributo data_criacao para datetime

# %%
df['data_criacao'] = pd.to_datetime(df['data_criacao'])

# %%
df['status_agendamento'] = df['status_agendamento'].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14518 entries, 0 to 14517
# Data columns (total 27 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  14518 non-null  int64
#  1   protocolo                           14518 non-null  object
#  2   tipo_retorno                        14518 non-null  int64
#  3   nome_paciente                       14518 non-null  object
#  4   data_nascimento                     14518 non-null  object
#  5   nome_mae                            14518 non-null  object
#  6   numero_celular                      14518 non-null  object
#  7   prontuario                          8367 non-null   float64
#  8   numero_telefone                     9735 non-null   object
#  9   email                               11506 non-null  object
#  10  genero                              14518 non-null  int64
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### Substituindo os valores NaN por 0

# %%
df['status_agendamento'] = df['status_agendamento'].fillna(0)

# %%
df
# Out:
#           id                 protocolo  tipo_retorno  \
# 0         88  202301181755359135778457             1
# 1       5023  202302231341593531386745             1
# 2       4512   20230217154540306821975             1
# 3       5727  202302281704491125985199             1
# 4          6  202301161755176828621602             1
# ...      ...                       ...           ...
# 14513  14687   20230519151820868583611             1
# 14514  14688   20230519151836885685296             1
# 14515  14689  202305191521521091241441             1
# 14516  14690  202305191522471148733497             1
# 14517  14691  202305191523391203031178             1
#
#                                  nome_paciente data_nascimento  \
# 0                     camila araujo dos santos      1983-06-03
# 1                       guiomar alves da silva      1963-10-22
# 2      Efig�nia Francisco da Conceição Lacerda      1962-09-20
# 3                      Valdeci Alves Fernandes      1959-06-23
# ...

# %%
df['data_hora_agendamento'] = df['data_hora_agendamento'].fillna('2023-01-01 00:00:00	')

# %%
df.head(553)
# Out:
#        id                 protocolo  tipo_retorno  \
# 0      88  202301181755359135778457             1
# 1    5023  202302231341593531386745             1
# 2    4512   20230217154540306821975             1
# 3    5727  202302281704491125985199             1
# 4       6  202301161755176828621602             1
# ..    ...                       ...           ...
# 548   541  202301232227172623183051             2
# 549   542  202301232235353144844630             1
# 550   543  202301232251194134709347             1
# 551   544     202301232253564648807             1
# 552   545  202301232314151283201283             1
#
#                                nome_paciente data_nascimento  \
# 0                   camila araujo dos santos      1983-06-03
# 1                     guiomar alves da silva      1963-10-22
# 2    Efig�nia Francisco da Conceição Lacerda      1962-09-20
# 3                    Valdeci Alves Fernandes      1959-06-23
# ...

# %%
df['data_hora_agendamento'] = pd.to_datetime(df['data_hora_agendamento'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14518 entries, 0 to 14517
# Data columns (total 27 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  14518 non-null  int64
#  1   protocolo                           14518 non-null  object
#  2   tipo_retorno                        14518 non-null  int64
#  3   nome_paciente                       14518 non-null  object
#  4   data_nascimento                     14518 non-null  object
#  5   nome_mae                            14518 non-null  object
#  6   numero_celular                      14518 non-null  object
#  7   prontuario                          8367 non-null   float64
#  8   numero_telefone                     9735 non-null   object
#  9   email                               11506 non-null  object
#  10  genero                              14518 non-null  int64
# ...

# %%
df.data_hora_agendamento.min()
# Out:
# Timestamp('2022-02-23 07:30:00')

# %%
df.data_hora_agendamento.max()
# Out:
# Timestamp('2023-08-16 08:00:00')

# %%
ano = df['data_hora_agendamento'].dt.year == 2023.0

# %%
mes =  df['data_hora_agendamento'].dt.month

# %%
mes
# Out:
# 0        1.0
# 1        3.0
# 2        3.0
# 3        1.0
# 4        4.0
#         ...
# 14513    1.0
# 14514    1.0
# 14515    1.0
# 14516    1.0
# 14517    1.0
# Name: data_hora_agendamento, Length: 14518, dtype: float64

# %%
mes.max()
# Out:
# 8.0

# %%
mes.min()
# Out:
# 1.0

# %%
agendamento2 = df.loc[(df['data_hora_agendamento'].dt.year == 2022) & (df['data_hora_agendamento'].dt.month == 2)]

# %%
agendamento2
# Out:
#         id                protocolo  tipo_retorno    nome_paciente  \
# 1048  1052  20230126122842531203592             1  Ivone Feliciano
#
#      data_nascimento                    nome_mae   numero_celular  prontuario  \
# 1048      1960-05-02  Benedita Balbino Feliciano  (62) 98461-6351    723699.0
#
#       numero_telefone                       email  ...  \
# 1048  (62) 98591-2169  vitoramorheithor@gmail.com  ...
#
#       tipo_confirmacao_agendamento observacao status_agendamento  \
# 1048                             1        NaN                2.0
#
#       data_hora_agendamento imagem_pedido  termo  \
# 1048    2022-02-23 07:30:00           NaN      1
#
#                      informacoes_adicionais_atendimento  usuario_id  \
# 1048   Atendimento por ordem de chegada, trazer exam...        14.0
#
#             data_criacao     data_atualizacao
# 1048 2023-01-26 09:27:29  2023-01-30 13:27:01
#
# [1 rows x 27 columns]

# %%
count2 = agendamento2['status_agendamento'].count()

# %%
count2
# Out:
# 1

# %%
agendamento3 = df.loc[(df['data_hora_agendamento'].dt.year == 2022) & (df['data_hora_agendamento'].dt.month == 3)]

# %%
agendamento3
# Out:
#         id                 protocolo  tipo_retorno            nome_paciente  \
# 4570  4540  202302171816071182169374             1  Itamar de Santana Grota
#
#      data_nascimento                    nome_mae   numero_celular  prontuario  \
# 4570      1958-08-27  Otacilia Trindade da Rocha  (62) 99941-3048   1350072.0
#
#       numero_telefone                 email  ...  \
# 4570  (62) 99982-1525  itamarks@hotmail.com  ...
#
#       tipo_confirmacao_agendamento observacao status_agendamento  \
# 4570                             3        NaN                2.0
#
#       data_hora_agendamento imagem_pedido  termo  \
# 4570    2022-03-28 07:30:00           NaN      1
#
#       informacoes_adicionais_atendimento  usuario_id        data_criacao  \
# 4570                                 NaN         0.0 2023-02-17 15:14:32
#
#          data_atualizacao
# 4570  2023-03-27 10:28:26
#
# [1 rows x 27 columns]

# %%
count3 = agendamento3.status_agendamento.count()

# %%
count3
# Out:
# 1

# %%
agendamento4 = df.loc[(df['data_hora_agendamento'].dt.year == 2022) & (df['data_hora_agendamento'].dt.month == 4)]

# %%
agendamento4
# Out:
#         id                 protocolo  tipo_retorno              nome_paciente  \
# 6432  6489  202303061237023874284491             1  ALDAIR GUIMAR�ES DA SILVA
# 6686  6751  202303071437323268119848             1  TEREZA BARRETO PACCAMICIO
# 7628  7726  202303141622304099996344             1     José de Souza Assunção
# 9152  9283  202303271419071571976214             1        HELIO NERY DE SOUSA
#
#      data_nascimento                    nome_mae   numero_celular  prontuario  \
# 6432      1957-06-10  Jazilva Guimar�es da silva  (62) 99636-4546   1454173.0
# 6686      1938-03-16            DOMINGAS BARRETO  (64) 99233-8838         NaN
# 7628      1956-03-28        Ana Martins de Souza   (62) 9966-5820         NaN
# 9152      1963-07-24      ANA TEREZINHA DE SOUSA  (62) 98151-1181   1076754.0
#
#      numero_telefone                         email  ...  \
# 6432             NaN    fernandaborbaa@hotmail.com  ...
# 6686             NaN   barretopaccamicio@gmail.com  ...
# ...

# %%
count4 = agendamento4.status_agendamento.count()

# %%
count4
# Out:
# 4

# %%
quantagenda = [count2, count3, count4]

# %%
quantagenda
# Out:
# [1, 1, 4]

# %%
df['Mes'], df['Ano'] = (df['data_hora_agendamento'].dt.month, df['data_hora_agendamento'].dt.year)

# %%
df
# Out:
#           id                 protocolo  tipo_retorno  \
# 0         88  202301181755359135778457             1
# 1       5023  202302231341593531386745             1
# 2       4512   20230217154540306821975             1
# 3       5727  202302281704491125985199             1
# 4          6  202301161755176828621602             1
# ...      ...                       ...           ...
# 14513  14687   20230519151820868583611             1
# 14514  14688   20230519151836885685296             1
# 14515  14689  202305191521521091241441             1
# 14516  14690  202305191522471148733497             1
# 14517  14691  202305191523391203031178             1
#
#                                  nome_paciente data_nascimento  \
# 0                     camila araujo dos santos      1983-06-03
# 1                       guiomar alves da silva      1963-10-22
# 2      Efig�nia Francisco da Conceição Lacerda      1962-09-20
# 3                      Valdeci Alves Fernandes      1959-06-23
# ...

# %%
mes = ['Fevereiro', 'Março', 'Abril']

# %%
mes
# Out:
# ['Fevereiro', 'Março', 'Abril']

# %%
quantagenda
# Out:
# [1, 1, 4]

# %%
plt.bar(mes, quantagenda, color='red')
plt.xticks(mes)
plt.ylabel('(Quantidade de agendamento por mês)')
plt.xlabel('Mês')
plt.title('Quantidade de agendamento por mês no ano de 2022')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
quant1 = [0, count2, 0]

# %%
quant1
# Out:
# [0, 1, 0]

# %%
quant2 = [0, count3, 0]

# %%
quant2
# Out:
# [0, 1, 0]

# %%
quant3 = [0, count4, 0]

# %%
quant3
# Out:
# [0, 4, 0]

# %%
barWidth = 0.25

# %%
plt.figure(figsize=(10,5))

# %%
quantidadeagendamentos = {
    'Aguardando': (count2, count3, count4),
    'Confirmado': (0, 0, 0),
    'Cancelado': (0, 0, 0),
}
r1 = np.arange(len(quantidadeagendamentos))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

# %%
plt.bar(r1, quant1, color='#6A5ACD', width = barWidth, label = 'Aguardando')
plt.bar(r2, quant2, color='#6495ED', width = barWidth, label = 'Confirmado')
plt.bar(r3, quant3, color='#00BFFF', width = barWidth, label = 'Cancelado')

plt.xlabel('Meses')
plt.xticks([r + barWidth for r in range(len(quant1))], ['Fevereiro', 'Março', 'Abril'])
plt.ylabel('Agendamentos')
plt.title('Quantidade de agendamentos 2022')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
meses = ("Fevereiro", "Março", "Abril")
quantidadeagendamentos = {
    'Aguardando': (count2, count3, count4),
    'Confirmado': (0, 0, 0),
    'Cancelado': (0, 0, 0),
}

label = np.arange(len(meses))
width = 0.25  
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for atribute, measurement in quantidadeagendamentos.items():
    offset = width * multiplier
    rects = ax.bar(label + offset, measurement, width, label = atribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1
    
ax.set_ylabel('Agendamentos')
ax.set_title('Quantidade de agendamento 2022')
ax.set_xticks(label + width, meses)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Analise agendamento 2023

# %% [markdown]
# #### Agendamento Total 2023

# %%
agendamentoTotal = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month)]

# %% [markdown]
# ---

# %%
agendamentoTotal.status_agendamento.count()
# Out:
# 14502

# %% [markdown]
# ---

# %% [markdown]
# ### Agendamento Janeiro

# %% [markdown]
# #### Total de agendamento em Janeiro

# %%
agendamentoJaneiro = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 1)]

# %%
agendamentoJaneiro.status_agendamento.count()
# Out:
# 9963

# %%
quantidadeJaneiro = agendamentoJaneiro.status_agendamento.count()
quantidadeJaneiro
# Out:
# 9963

# %% [markdown]
# ---

# %% [markdown]
# #### Agendamento Status Aguardando

# %%
agendamentoAguardandoJaneiro = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 1) & (df['status_agendamento'] == 1.0) ]

# %%
agendamentoAguardandoJaneiro.head()
# Out:
#       id                 protocolo  tipo_retorno  \
# 109  121  202301181755366996934407             1
# 123  131  202301181755368448266193             1
# 126  134  202301181755369453690657             1
# 140  148  202301181755374472285274             1
# 164  173  202301181755391011183801             1
#
#                                 nome_paciente data_nascimento  \
# 109                   PERCILIA RAIMUNDO PINTO      1957-06-17
# 123                   Stefany Fabiana Ribeiro      2006-10-19
# 126                         Luzinete da silva      2023-01-22
# 140            Kamilla Laleska Alves Sobrinho      1995-06-28
# 164  Maurivania Bernardo da Conceição Catalan      1991-03-27
#
#                               nome_mae   numero_celular  prontuario  \
# 109               Am�lia Dias da Silva  (62) 98524-4974    676897.0
# 123  Patricia Cristina Augusto Ribeiro  (62) 98307-7937    654629.0
# 126           Maria das dores da silva  (62) 99858-4767    826108.0
# ...

# %%
quantidadeAguardandoJaneiro = agendamentoAguardandoJaneiro.status_agendamento.count()

# %%
quantidadeAguardandoJaneiro
# Out:
# 86

# %% [markdown]
# ---

# %% [markdown]
# #### Agendamento status Confirmado

# %%
agendamentoConfirmadoJaneiro = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 1) & (df['status_agendamento'] == 2.0) ]

# %%
agendamentoConfirmadoJaneiro.head()
# Out:
#       id                 protocolo  tipo_retorno            nome_paciente  \
# 3   5727  202302281704491125985199             1  Valdeci Alves Fernandes
# 34  9304  202303271628401132540399             1    João Batista da Silva
# 72    81  202301171755300789561682             1     Renata da Cruz Gomes
# 73    82  202301171755300794430520             1     Renata da Cruz Gomes
# 74    83  202301171755300809291774             1     Renata da Cruz Gomes
#
#    data_nascimento                       nome_mae   numero_celular  \
# 3       1959-06-23             Maria Alves Garcia  (64) 99252-0240
# 34      1945-01-04       Joana Francisca da Silva  (62) 99328-4516
# 72      1986-12-12  Maria Cristina Vieira da Cruz  (62) 98601-7064
# 73      1986-12-12  Maria Cristina Vieira da Cruz  (62) 98601-7064
# 74      1986-12-12  Maria Cristina Vieira da Cruz  (62) 98601-7064
#
#     prontuario  numero_telefone                     email  ...  \
# ...

# %%
quantidadeConfirmadoJaneiro = agendamentoConfirmadoJaneiro.status_agendamento.count()

# %%
quantidadeConfirmadoJaneiro
# Out:
# 58

# %% [markdown]
# ---

# %% [markdown]
# #### Agendamento status Cancelado

# %%
agendamentoCanceladoJaneiro = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 1) & (df['status_agendamento'] == 3.0) ]

# %%
agendamentoCanceladoJaneiro.head()
# Out:
#     id                 protocolo  tipo_retorno  \
# 0   88  202301181755359135778457             1
# 19  27  202301171755271916875068             2
# 20  29  202301171755273879672399             1
# 25  35  202301171755277971357481             1
# 32  42  202301171755279084303616             1
#
#                      nome_paciente data_nascimento                   nome_mae  \
# 0         camila araujo dos santos      1983-06-03    nilda araujo dos santos
# 19             ELIAS LUIZ FERREIRA      1947-11-15         JOVENILIA FERREIRA
# 20  LETICIA PRISLEY AVELINO COELHO      1995-03-07  ELIZANGELA AVELINO COELHO
# 25        Maria de Lourdes Pereira      1959-09-29       Aladia Amaro Pereira
# 32    LUIZ CARLOS GONTIJO DA SILVA      1963-08-04       MARIA NILMA DA SILVA
#
#      numero_celular  prontuario  numero_telefone                      email  \
# 0   (62) 99172-6875         0.0              NaN                        NaN
# ...

# %%
quantidadeCanceladoJaneiro = agendamentoCanceladoJaneiro.status_agendamento.count()

# %%
quantidadeCanceladoJaneiro
# Out:
# 2055

# %% [markdown]
# ---

# %% [markdown]
# #### Agendamentos não cadastrados

# %%
agendamentoNaoCadastradoJaneiro = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 1) & (df['status_agendamento'] == 0.0) ]

# %%
agendamentoNaoCadastradoJaneiro.head()
# Out:
#         id                 protocolo  tipo_retorno  \
# 105    117  202301181755366413699064             1
# 110  11656  202304201326033602696555             1
# 127  13751  202305111147491582702310             1
# 154    163  202301181755384319055709             2
# 175  13830  202305111736432058680648             1
#
#                      nome_paciente data_nascimento  \
# 105        Stefany Fabiana Ribeiro      2006-10-19
# 110        Manuel ferreira Barbosa      1931-01-24
# 127  Caio Gabriel Santos da Paixão      2020-12-19
# 154      Levone cezario Boaventura      1952-09-27
# 175  Vanda Lucia Severino da costa      1957-02-10
#
#                               nome_mae   numero_celular  prontuario  \
# 105  Patricia Cristina Augusto Ribeiro  (62) 98307-7937    654629.0
# 110               Maria Lina dos Anjos  (64) 99347-2104         NaN
# 127           Vanessa Silva dos Santos  (64) 99342-0552         NaN
# 154         Firmina cezaria Boaventura  (61) 98633-7471         0.0
# ...

# %%
quantidadeNaoCadastradoJaneiro = agendamentoNaoCadastradoJaneiro.status_agendamento.count()

# %%
quantidadeNaoCadastradoJaneiro
# Out:
# 7764

# %% [markdown]
# ---

# %% [markdown]
# ### Total de agendamento Fevereiro

# %% [markdown]
# #### Agendamento Total Fevereiro

# %%
agendamentoFevereiro = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 2)]

# %%
agendamentoFevereiro
# Out:
#         id                 protocolo  tipo_retorno  \
# 6       85  202301181755319885081338             1
# 10      87  202301181755355038448776             1
# 30      40  202301171755278626012938             1
# 31      41  202301171755279059127905             1
# 45      54  202301171755287592502613             2
# ...    ...                       ...           ...
# 3857  3806  202302141414141936371450             2
# 4405  4354  202302161732142314130905             1
# 4613  4587  202302172143381353351108             1
# 5075  5059  202302231535172069118016             1
# 6054  6102  202303021515273640269420             1
#
#                               nome_paciente data_nascimento  \
# 6                 Emanuel Soares dos Santos      2021-09-27
# 10            edilamar silva menezes santos      1977-07-08
# 30                    Aurelio Pereira Leite      1966-12-24
# 31                  maiza de brito da silva      1964-03-30
# ...

# %%
agendamentoTotalFevereiro = agendamentoFevereiro.status_agendamento.count()

# %%
agendamentoTotalFevereiro
# Out:
# 283

# %% [markdown]
# ---

# %% [markdown]
# #### Agendamentos status Aguardando

# %%
agendamentoAguardandoFevereiro = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 2) & (df['status_agendamento'] == 1.0) ]

# %%
agendamentoAguardandoFevereiro
# Out:
# Empty DataFrame
# Columns: [id, protocolo, tipo_retorno, nome_paciente, data_nascimento, nome_mae, numero_celular, prontuario, numero_telefone, email, genero, nome_medico, data_ultima_consulta, tipo_vaga, data_alta_internacao, especialidade_medica, tipo_marca, tipo_confirmacao_agendamento, observacao, status_agendamento, data_hora_agendamento, imagem_pedido, termo, informacoes_adicionais_atendimento, usuario_id, data_criacao, data_atualizacao, Mes, Ano]
# Index: []
#
# [0 rows x 29 columns]

# %%
quantidadeAguardandoFevereiro = agendamentoAguardandoFevereiro.status_agendamento.count()

# %%
quantidadeAguardandoFevereiro
# Out:
# 0

# %% [markdown]
# ---

# %% [markdown]
# #### Status agendamento Confirmado

# %%
agendamentoConfirmadoFevereiro = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 2) & (df['status_agendamento'] == 2.0) ]

# %%
agendamentoConfirmadoFevereiro
# Out:
#         id                 protocolo  tipo_retorno  \
# 6       85  202301181755319885081338             1
# 10      87  202301181755355038448776             1
# 30      40  202301171755278626012938             1
# 31      41  202301171755279059127905             1
# 45      54  202301171755287592502613             2
# ...    ...                       ...           ...
# 3857  3806  202302141414141936371450             2
# 4405  4354  202302161732142314130905             1
# 4613  4587  202302172143381353351108             1
# 5075  5059  202302231535172069118016             1
# 6054  6102  202303021515273640269420             1
#
#                               nome_paciente data_nascimento  \
# 6                 Emanuel Soares dos Santos      2021-09-27
# 10            edilamar silva menezes santos      1977-07-08
# 30                    Aurelio Pereira Leite      1966-12-24
# 31                  maiza de brito da silva      1964-03-30
# ...

# %%
quantidadeConfirmadoFevereiro = agendamentoConfirmadoFevereiro.status_agendamento.count()

# %%
quantidadeConfirmadoFevereiro
# Out:
# 281

# %% [markdown]
# ---

# %% [markdown]
# #### Status agendamento Cancelado

# %%
agendamentoCanceladoFevereiro = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 2) & (df['status_agendamento'] == 3.0) ]

# %%
agendamentoCanceladoFevereiro
# Out:
#         id                 protocolo  tipo_retorno              nome_paciente  \
# 418    416  202301231043471312381739             1  gasparina alves de araujo
# 1695  1646  202302011106532094278564             1  Neiva dos Santos Ferreira
#
#      data_nascimento                      nome_mae   numero_celular  \
# 418       1945-04-26            ana rosa de araujo  (62) 99974-5607
# 1695      1985-02-16  Clarinda Oliveira dos santos  (62) 99508-7514
#
#       prontuario numero_telefone                    email  ...  \
# 418     354720.0             NaN                      NaN  ...
# 1695         0.0             NaN  adeneiva_25@hotmail.com  ...
#
#       status_agendamento data_hora_agendamento imagem_pedido  termo  \
# 418                  3.0   2023-02-14 14:30:00           NaN      1
# 1695                 3.0   2023-02-17 15:00:00           NaN      1
#
#      informacoes_adicionais_atendimento  usuario_id        data_criacao  \
# ...

# %%
quantidadeCanceladoFevereiro = agendamentoCanceladoFevereiro.status_agendamento.count()

# %%
quantidadeCanceladoFevereiro
# Out:
# 2

# %% [markdown]
# ---

# %% [markdown]
# #### Status agendamento não registrado

# %%
agendamentoNaoRegistradoFevereiro = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 2) & (df['status_agendamento'] == 0.0) ]

# %%
agendamentoNaoRegistradoFevereiro
# Out:
# Empty DataFrame
# Columns: [id, protocolo, tipo_retorno, nome_paciente, data_nascimento, nome_mae, numero_celular, prontuario, numero_telefone, email, genero, nome_medico, data_ultima_consulta, tipo_vaga, data_alta_internacao, especialidade_medica, tipo_marca, tipo_confirmacao_agendamento, observacao, status_agendamento, data_hora_agendamento, imagem_pedido, termo, informacoes_adicionais_atendimento, usuario_id, data_criacao, data_atualizacao, Mes, Ano]
# Index: []
#
# [0 rows x 29 columns]

# %%
quantidadeNaoRegistradoFevereiro = agendamentoNaoRegistradoFevereiro.status_agendamento.count()

# %%
quantidadeNaoRegistradoFevereiro
# Out:
# 0

# %% [markdown]
# ### Total de Agendamento Março

# %% [markdown]
# #### Agendamento total Março

# %%
agendamentoMarco = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 3)]

# %%
agendamentoMarco
# Out:
#           id                 protocolo  tipo_retorno  \
# 1       5023  202302231341593531386745             1
# 2       4512   20230217154540306821975             1
# 12        84  202301171755311942151098             1
# 29        39  202301171755278286890337             1
# 38        48  202301171755280911440962             2
# ...      ...                       ...           ...
# 9130    9259   20230327115202908475025             1
# 9131    9260   20230327115232940241878             1
# 9311    9452  202303281521111584732807             1
# 9423    9564    2023032911260884239211             1
# 10765  10922  202304131343101860594369             1
#
#                                  nome_paciente data_nascimento  \
# 1                       guiomar alves da silva      1963-10-22
# 2      Efig�nia Francisco da Conceição Lacerda      1962-09-20
# 12             Daniella Oliveira do Nascimento      1996-07-19
# 29                     ERCIDIA MOREIRA MACHADO      1961-09-16
# ...

# %%
quantidadeMarco = agendamentoMarco.status_agendamento.count()
quantidadeMarco
# Out:
# 1112

# %% [markdown]
# ---

# %% [markdown]
# #### Status agendamento aguardando

# %%
agendamentoAguardandoMarco = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 3) & (df['status_agendamento'] == 1.0) ]

# %%
agendamentoAguardandoMarco
# Out:
# Empty DataFrame
# Columns: [id, protocolo, tipo_retorno, nome_paciente, data_nascimento, nome_mae, numero_celular, prontuario, numero_telefone, email, genero, nome_medico, data_ultima_consulta, tipo_vaga, data_alta_internacao, especialidade_medica, tipo_marca, tipo_confirmacao_agendamento, observacao, status_agendamento, data_hora_agendamento, imagem_pedido, termo, informacoes_adicionais_atendimento, usuario_id, data_criacao, data_atualizacao, Mes, Ano]
# Index: []
#
# [0 rows x 29 columns]

# %%
quantidadeAguardandoMarco = agendamentoAguardandoMarco.status_agendamento.count()

# %%
quantidadeAguardandoMarco
# Out:
# 0

# %% [markdown]
# #### Status agendamento Confirmado

# %%
agendamentoConfirmadoMarco = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 3) & (df['status_agendamento'] == 2.0) ]

# %%
agendamentoConfirmadoMarco
# Out:
#           id                 protocolo  tipo_retorno  \
# 1       5023  202302231341593531386745             1
# 2       4512   20230217154540306821975             1
# 12        84  202301171755311942151098             1
# 29        39  202301171755278286890337             1
# 38        48  202301171755280911440962             2
# ...      ...                       ...           ...
# 9130    9259   20230327115202908475025             1
# 9131    9260   20230327115232940241878             1
# 9311    9452  202303281521111584732807             1
# 9423    9564    2023032911260884239211             1
# 10765  10922  202304131343101860594369             1
#
#                                  nome_paciente data_nascimento  \
# 1                       guiomar alves da silva      1963-10-22
# 2      Efig�nia Francisco da Conceição Lacerda      1962-09-20
# 12             Daniella Oliveira do Nascimento      1996-07-19
# 29                     ERCIDIA MOREIRA MACHADO      1961-09-16
# ...

# %%
quantidadeConfirmadoMarco = agendamentoConfirmadoMarco.status_agendamento.count()

# %%
quantidadeConfirmadoMarco
# Out:
# 1106

# %% [markdown]
# ---

# %% [markdown]
# #### Status agendamento Cancelado

# %%
agendamentoCanceladoMarco = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 3) & (df['status_agendamento'] == 3.0) ]

# %%
agendamentoCanceladoMarco
# Out:
#         id                 protocolo  tipo_retorno  \
# 234    236   20230119153717986717680             1
# 3026  2971  202302091740024280929423             1
# 3234  3180  202302101141513622929353             1
# 6506  6569   20230306172014216380120             1
# 6870  6939  202303081518041925339989             1
# 7440  7528   20230313152952386406565             1
#
#                       nome_paciente data_nascimento  \
# 234      Sinval Pereira de Oliveira      1963-11-08
# 3026         Benedita Rosa Da Silva      1944-10-10
# 3234      CARLOS BATISTA DOS SANTOS      1948-11-02
# 6506  adriana paula borges da silva      1982-08-12
# 6870       ANDRIELE FERREIRA PASSOS      2003-05-23
# 7440         Abilio Francisco Póvoa      1940-04-09
#
#                            nome_mae   numero_celular   prontuario  \
# 234       Maria Lourenã de Oliveira  (62) 99685-0884     601345.0
# 3026  Joventina Senhorinha de Jesus  (62) 99356-2317          NaN
# ...

# %%
quantidadeCanceladoMarco = agendamentoCanceladoMarco.status_agendamento.count()

# %%
quantidadeCanceladoMarco
# Out:
# 6

# %% [markdown]
# ---

# %%
agendamentoNaoRegistradoMarco = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 3) & (df['status_agendamento'] == 0.0) ]

# %%
agendamentoNaoRegistradoMarco
# Out:
# Empty DataFrame
# Columns: [id, protocolo, tipo_retorno, nome_paciente, data_nascimento, nome_mae, numero_celular, prontuario, numero_telefone, email, genero, nome_medico, data_ultima_consulta, tipo_vaga, data_alta_internacao, especialidade_medica, tipo_marca, tipo_confirmacao_agendamento, observacao, status_agendamento, data_hora_agendamento, imagem_pedido, termo, informacoes_adicionais_atendimento, usuario_id, data_criacao, data_atualizacao, Mes, Ano]
# Index: []
#
# [0 rows x 29 columns]

# %%
quantidadeNaoregistradoMarco = agendamentoNaoRegistradoMarco.status_agendamento.count()

# %%
quantidadeNaoregistradoMarco
# Out:
# 0

# %% [markdown]
# ---

# %% [markdown]
# ### Total agendamentos Abril

# %% [markdown]
# #### Total de agendamentos

# %%
agendamentoAbril = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 4)]

# %%
agendamentoAbril
# Out:
#           id                 protocolo  tipo_retorno  \
# 4          6  202301161755176828621602             1
# 5       9293  202303271445193220317275             1
# 7         20  202301171755268702647389             1
# 8         19  202301171755268503202354             1
# 9       9295  202303271500194164662465             1
# ...      ...                       ...           ...
# 11527  11677  202304201514021805650250             2
# 11701  11851  202304241202544276157615             1
# 11719  11869  202304241306484001674690             1
# 11770  11920  202304241555441744878498             1
# 11857  12007   20230424211524382101178             1
#
#                               nome_paciente data_nascimento  \
# 4       Maria Alice Souza dos Santos Barros      1982-02-22
# 5              Aparecida Francisca de Sousa      1981-05-22
# 7                     JOSE LOURENã DA SILVA      1953-09-04
# 8                    JOSE EDMILSON DA SILVA      1968-08-02
# ...

# %%
quantidadeTotalAbril = agendamentoAbril.status_agendamento.count()

# %%
quantidadeTotalAbril
# Out:
# 1488

# %% [markdown]
# ---

# %% [markdown]
# #### Status agendamento Aguardando

# %%
agendamentoAguardandoAbril = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 4) & (df['status_agendamento'] == 1.0) ]

# %%
agendamentoAguardandoAbril
# Out:
#       id               protocolo  tipo_retorno                nome_paciente  \
# 411  410  2023012200154046438707             1  Patrocina Almeida goncalves
#
#     data_nascimento           nome_mae   numero_celular  prontuario  \
# 411      1946-03-10  Ant�nia damasceno  (62) 99818-7302         NaN
#
#      numero_telefone                         email  ...  status_agendamento  \
# 411  (62) 99818-7302  patrociniaalmeida1@gmail.com  ...                 1.0
#
#     data_hora_agendamento imagem_pedido  termo  \
# 411   2023-04-24 07:30:00           NaN      1
#
#     informacoes_adicionais_atendimento  usuario_id        data_criacao  \
# 411            AVALIAÇÃO DE MARCAPASSO         5.0 2023-01-21 21:14:31
#
#         data_atualizacao  Mes     Ano
# 411  2023-04-15 08:16:33  4.0  2023.0
#
# [1 rows x 29 columns]

# %%
quantidadeAguardandoAbril = agendamentoAguardandoAbril.status_agendamento.count()
quantidadeAguardandoAbril
# Out:
# 1

# %% [markdown]
# #### Status Confirmado

# %%
agendamentoConfirmadoAbril = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 4) & (df['status_agendamento'] == 2.0) ]

# %%
agendamentoConfirmadoAbril
# Out:
#           id                 protocolo  tipo_retorno  \
# 4          6  202301161755176828621602             1
# 5       9293  202303271445193220317275             1
# 7         20  202301171755268702647389             1
# 8         19  202301171755268503202354             1
# 9       9295  202303271500194164662465             1
# ...      ...                       ...           ...
# 11527  11677  202304201514021805650250             2
# 11701  11851  202304241202544276157615             1
# 11719  11869  202304241306484001674690             1
# 11770  11920  202304241555441744878498             1
# 11857  12007   20230424211524382101178             1
#
#                               nome_paciente data_nascimento  \
# 4       Maria Alice Souza dos Santos Barros      1982-02-22
# 5              Aparecida Francisca de Sousa      1981-05-22
# 7                     JOSE LOURENã DA SILVA      1953-09-04
# 8                    JOSE EDMILSON DA SILVA      1968-08-02
# ...

# %%
quantidadeConfirmadoAbril = agendamentoConfirmadoAbril.status_agendamento.count()
quantidadeConfirmadoAbril
# Out:
# 1474

# %% [markdown]
# ---

# %% [markdown]
# #### Status agendamento Cancelado

# %%
agendamentoCanceladoAbril = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 4) & (df['status_agendamento'] == 3.0) ]
agendamentoCanceladoAbril
# Out:
#           id                 protocolo  tipo_retorno  \
# 1026    1029  202301260031292652401891             1
# 1645    1596  202301312037133214711427             1
# 2335    2278  202302071204023811135838             1
# 2363    2306   20230207132323213136737             1
# 5287    5294  202302242006372362843605             1
# 6239    6293  202303031711232746916705             1
# 7134    7204   20230309191636155936949             2
# 7600    7688  202303141346582904753083             1
# 8275    8404  202303201145351979581524             1
# 9789    9927  202304012037571649642477             1
# 9964   10104  202304041141063441437231             1
# 10523  10667  202304111511002286054032             1
# 10721  10878   20230412201513353646593             1
#
#                             nome_paciente data_nascimento  \
# 1026            regina de oliveira farias      1962-05-08
# 1645   Rosely monteiro de Ara�jo Ferreira      1964-12-10
# ...

# %%
quantidadeCanceladoAbril = agendamentoCanceladoAbril.status_agendamento.count()
quantidadeCanceladoAbril
# Out:
# 13

# %% [markdown]
# ---

# %% [markdown]
# #### Agendamento não registrados

# %%
agendamentoNaoRegistradoAbril = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 4) & (df['status_agendamento'] == 0.0) ]
agendamentoNaoRegistradoAbril
# Out:
# Empty DataFrame
# Columns: [id, protocolo, tipo_retorno, nome_paciente, data_nascimento, nome_mae, numero_celular, prontuario, numero_telefone, email, genero, nome_medico, data_ultima_consulta, tipo_vaga, data_alta_internacao, especialidade_medica, tipo_marca, tipo_confirmacao_agendamento, observacao, status_agendamento, data_hora_agendamento, imagem_pedido, termo, informacoes_adicionais_atendimento, usuario_id, data_criacao, data_atualizacao, Mes, Ano]
# Index: []
#
# [0 rows x 29 columns]

# %%
quantidadenaoRegistradoAbril = agendamentoNaoRegistradoAbril.status_agendamento.count()
quantidadenaoRegistradoAbril
# Out:
# 0

# %% [markdown]
# ---

# %% [markdown]
# ### Total de agendamentos em Maio

# %%
agendamentoMaio = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 5)] 
agendamentoMaio
# Out:
#           id                 protocolo  tipo_retorno  \
# 57      9322  202303271754232231222506             1
# 115      126  202301181755367995609255             1
# 116    10855  202304121838432872908736             1
# 120    10064  202304031920071852886133             1
# 179      186  202301190132343676950043             1
# ...      ...                       ...           ...
# 14327  14500   20230518115519578546221             1
# 14336  14509  202305181239203347717162             1
# 14342  14515   20230518130516683982991             1
# 14344  14517  202305181313381210688663             1
# 14483  14657  202305191245484156952830             1
#
#                         nome_paciente data_nascimento  \
# 57           Margarida Lourenço Maria      1941-12-31
# 115          Alzira de Moraes Barbosa      1951-09-08
# 116           Leonardo Batista Mendes      2023-11-06
# 120       Coquelim Batista de Souza 0      1937-09-02
# ...

# %%
quantidadeMaio = agendamentoMaio.status_agendamento.count()
quantidadeMaio
# Out:
# 1470

# %% [markdown]
# ---

# %% [markdown]
# #### Status agendamento Aguardando

# %%
agendamentoAguardandoMaio = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 5) & (df['status_agendamento'] == 1.0) ]
agendamentoAguardandoMaio
# Out:
# Empty DataFrame
# Columns: [id, protocolo, tipo_retorno, nome_paciente, data_nascimento, nome_mae, numero_celular, prontuario, numero_telefone, email, genero, nome_medico, data_ultima_consulta, tipo_vaga, data_alta_internacao, especialidade_medica, tipo_marca, tipo_confirmacao_agendamento, observacao, status_agendamento, data_hora_agendamento, imagem_pedido, termo, informacoes_adicionais_atendimento, usuario_id, data_criacao, data_atualizacao, Mes, Ano]
# Index: []
#
# [0 rows x 29 columns]

# %%
quantidadeAguardandoMaio = agendamentoAguardandoMaio.status_agendamento.count()
quantidadeAguardandoMaio
# Out:
# 0

# %% [markdown]
# ---

# %% [markdown]
# #### Status agendamento Confirmado

# %%
agendamentoConfirmadoMaio = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 5) & (df['status_agendamento'] == 2.0) ]
agendamentoConfirmadoMaio
# Out:
#           id                 protocolo  tipo_retorno  \
# 57      9322  202303271754232231222506             1
# 115      126  202301181755367995609255             1
# 116    10855  202304121838432872908736             1
# 120    10064  202304031920071852886133             1
# 179      186  202301190132343676950043             1
# ...      ...                       ...           ...
# 14327  14500   20230518115519578546221             1
# 14336  14509  202305181239203347717162             1
# 14342  14515   20230518130516683982991             1
# 14344  14517  202305181313381210688663             1
# 14483  14657  202305191245484156952830             1
#
#                         nome_paciente data_nascimento  \
# 57           Margarida Lourenço Maria      1941-12-31
# 115          Alzira de Moraes Barbosa      1951-09-08
# 116           Leonardo Batista Mendes      2023-11-06
# 120       Coquelim Batista de Souza 0      1937-09-02
# ...

# %%
quantidadeConfirmadoMaio = agendamentoConfirmadoMaio.status_agendamento.count()
quantidadeConfirmadoMaio
# Out:
# 1461

# %% [markdown]
# ---

# %% [markdown]
# #### Status agendamento Cancelado

# %%
agendamentoCanceladoMaio = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 5) & (df['status_agendamento'] == 3.0) ]
agendamentoCanceladoMaio
# Out:
#           id                 protocolo  tipo_retorno  \
# 2836    2778  202302082209463668745132             1
# 5095    5080  202302231713183941405879             1
# 8014    8123  202303161632351245316318             1
# 11013  11166  202304171204011528456812             1
# 12766  12928  202305031523023311945319             1
# 12793  12955  202305031713511694019809             1
# 12920  13083  202305041638244161375316             1
# 14170  14343  202305171340462514984653             1
#
#                       nome_paciente data_nascimento  \
# 2836       Delaudice Alves da Silva      1949-12-31
# 5095   Ivoneide Barbosa de Oliveira      1971-08-25
# 8014    maria das dores de oliveira      1964-01-05
# 11013    Gildesio arruda de Santana      1977-08-30
# 12766    Laurides de Sousa Oliveira      1959-06-04
# 12793   MARIA DAS DORES DE OLIVEIRA      1964-01-06
# 12920       MARCELO MENEZES DE LIMA      1996-01-13
# 14170    Antonio Caetano de Azevedo      1945-06-14
#
# ...

# %%
quantidadeCanceladoMaio = agendamentoCanceladoMaio.status_agendamento.count()
quantidadeCanceladoMaio
# Out:
# 8

# %% [markdown]
# ---

# %% [markdown]
# #### Agendamentos não registrado

# %%
agendamentoNaoRegistradoMaio = df.loc[(df['data_hora_agendamento'].dt.year == 2023) & (df['data_hora_agendamento'].dt.month == 5) & (df['status_agendamento'] == 0.0) ]
agendamentoNaoRegistradoMaio
# Out:
#           id                 protocolo  tipo_retorno  \
# 11147  11300  202304181159161631867489             1
#
#                   nome_paciente data_nascimento                nome_mae  \
# 11147  Vitor Gabriel dos Santos      2022-01-22  Cleonice bito de souza
#
#         numero_celular  prontuario numero_telefone                    email  \
# 11147  (62) 99260-8624         NaN    (35) 17-5828  cleonicebito2@gmail.com
#
#        ...  status_agendamento data_hora_agendamento imagem_pedido  termo  \
# 11147  ...                 0.0   2023-05-04 12:30:00           NaN      1
#
#       informacoes_adicionais_atendimento  usuario_id        data_criacao  \
# 11147                                NaN         NaN 2023-04-18 08:59:16
#
#           data_atualizacao  Mes     Ano
# 11147  2023-04-19 10:46:36  5.0  2023.0
#
# [1 rows x 29 columns]

# %%
quantidadeNaoRegistradoMaio = agendamentoNaoRegistradoMaio.status_agendamento.count()
quantidadeNaoRegistradoMaio
# Out:
# 1

# %% [markdown]
# ---

# %%
meses = ("Janeiro", "Fevereiro", "Março", "Abril")
quantidadeagendamentos = {
    'Total Mensal':(quantidadeJaneiro, agendamentoTotalFevereiro, quantidadeMarco, quantidadeTotalAbril),
    'Aguardando': (quantidadeAguardandoJaneiro, quantidadeAguardandoFevereiro, quantidadeAguardandoMarco, quantidadeAguardandoAbril),
    'Confirmado': (quantidadeConfirmadoJaneiro, quantidadeConfirmadoFevereiro, quantidadeConfirmadoMarco, quantidadeConfirmadoAbril),
    'Cancelado': (quantidadeCanceladoJaneiro, quantidadeCanceladoFevereiro, quantidadeCanceladoMarco, quantidadeCanceladoAbril),
    'Não Registrado': (quantidadeNaoCadastradoJaneiro, quantidadeNaoRegistradoFevereiro, quantidadeNaoregistradoMarco, quantidadenaoRegistradoAbril
),
}


label = np.arange(len(meses))
width = 0.18
multiplier = 0
font = 20

fig, ax = plt.subplots(layout='constrained', figsize = (17, 10))

for atribute, measurement in quantidadeagendamentos.items():
    offset = width * multiplier
    rects = ax.bar(label + offset, measurement, width, label = atribute)
    ax.bar_label(rects, padding=10)
    multiplier += 1

ax.set_ylabel('Agendamentos', fontsize=15, color='blue')
ax.set_title('Quantidade de agendamento por status - 2023', fontsize = font)
ax.set_xticks(label, meses, color='blue', fontsize=15)
ax.legend(fontsize = 12)
ax.set_ylim(0, 12000)
ax.tick_params(axis='x', labelsize=14, color='blue')
ax.tick_params(axis='y', labelsize=14)
plt.savefig("analise1.pdf")
plt.show()
